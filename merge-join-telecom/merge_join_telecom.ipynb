# %%
import pandas as pd

# %%
train = pd.read_csv('/content/train.csv')
event =  pd.read_csv('/content/event_type.csv')
severity = pd.read_csv('/content/severity_type.csv')
resource = pd.read_csv('/content/severity_type.csv')
log = pd.read_csv('/content/log_feature.csv')

# %%
severity
# Out:
#          id    severity_type
# 0      6597  severity_type 2
# 1      8011  severity_type 2
# 2      2597  severity_type 2
# 3      5022  severity_type 1
# 4      6852  severity_type 1
# ...     ...              ...
# 18547  3761  severity_type 1
# 18548  8720  severity_type 1
# 18549  6488  severity_type 2
# 18550   878  severity_type 2
# 18551  4464  severity_type 1
#
# [18552 rows x 2 columns]

# %%
log
# Out:
#          id  log_feature  volume
# 0      6597   feature 68       6
# 1      8011   feature 68       7
# 2      2597   feature 68       1
# 3      5022  feature 172       2
# 4      5022   feature 56       1
# ...     ...          ...     ...
# 58666  8720  feature 209       1
# 58667  6488   feature 54       3
# 58668   878   feature 62       1
# 58669  4464  feature 209       1
# 58670  4464   feature 87       2
#
# [58671 rows x 3 columns]

# %% [markdown]
# ###1 Merge Tables

# %%
merged = train.merge(event)
merged
# Out:
#           id       location  fault_severity     event_type
# 0      14121   location 118               1  event_type 34
# 1      14121   location 118               1  event_type 35
# 2       9320    location 91               0  event_type 34
# 3       9320    location 91               0  event_type 35
# 4      14394   location 152               1  event_type 35
# ...      ...            ...             ...            ...
# 12463    870   location 167               0  event_type 35
# 12464  18068   location 106               0  event_type 20
# 12465  14111  location 1086               2  event_type 15
# 12466  15189     location 7               0  event_type 11
# 12467  17067   location 885               0  event_type 11
#
# [12468 rows x 4 columns]

# %%
merged2 = merged.merge(severity)
merged2
# Out:
#           id       location  fault_severity     event_type    severity_type
# 0      14121   location 118               1  event_type 34  severity_type 2
# 1      14121   location 118               1  event_type 35  severity_type 2
# 2       9320    location 91               0  event_type 34  severity_type 2
# 3       9320    location 91               0  event_type 35  severity_type 2
# 4      14394   location 152               1  event_type 35  severity_type 2
# ...      ...            ...             ...            ...              ...
# 12463    870   location 167               0  event_type 35  severity_type 2
# 12464  18068   location 106               0  event_type 20  severity_type 1
# 12465  14111  location 1086               2  event_type 15  severity_type 2
# 12466  15189     location 7               0  event_type 11  severity_type 1
# 12467  17067   location 885               0  event_type 11  severity_type 1
#
# [12468 rows x 5 columns]

# %%
merged3 = merged2.merge(resource)
merged3
# Out:
#           id       location  fault_severity     event_type    severity_type
# 0      14121   location 118               1  event_type 34  severity_type 2
# 1      14121   location 118               1  event_type 35  severity_type 2
# 2       9320    location 91               0  event_type 34  severity_type 2
# 3       9320    location 91               0  event_type 35  severity_type 2
# 4      14394   location 152               1  event_type 35  severity_type 2
# ...      ...            ...             ...            ...              ...
# 12463    870   location 167               0  event_type 35  severity_type 2
# 12464  18068   location 106               0  event_type 20  severity_type 1
# 12465  14111  location 1086               2  event_type 15  severity_type 2
# 12466  15189     location 7               0  event_type 11  severity_type 1
# 12467  17067   location 885               0  event_type 11  severity_type 1
#
# [12468 rows x 5 columns]

# %%
merged_final = merged3.merge(log)
merged_final
# Out:
#           id      location  fault_severity     event_type    severity_type  \
# 0      14121  location 118               1  event_type 34  severity_type 2
# 1      14121  location 118               1  event_type 34  severity_type 2
# 2      14121  location 118               1  event_type 35  severity_type 2
# 3      14121  location 118               1  event_type 35  severity_type 2
# 4       9320   location 91               0  event_type 34  severity_type 2
# ...      ...           ...             ...            ...              ...
# 46726  15189    location 7               0  event_type 11  severity_type 1
# 46727  15189    location 7               0  event_type 11  severity_type 1
# 46728  17067  location 885               0  event_type 11  severity_type 1
# 46729  17067  location 885               0  event_type 11  severity_type 1
# 46730  17067  location 885               0  event_type 11  severity_type 1
#
#        log_feature  volume
# 0      feature 312      19
# ...

# %% [markdown]
# ###2 Divide dataset into two dataframes.

# %%
df_1 = merged_final.iloc[:1000,]
df_2 = merged_final.iloc[1000:,]
# Out:
#         id       location  fault_severity     event_type    severity_type  \
# 0    14121   location 118               1  event_type 34  severity_type 2
# 1    14121   location 118               1  event_type 34  severity_type 2
# 2    14121   location 118               1  event_type 35  severity_type 2
# 3    14121   location 118               1  event_type 35  severity_type 2
# 4     9320    location 91               0  event_type 34  severity_type 2
# ..     ...            ...             ...            ...              ...
# 995  15486   location 821               0  event_type 11  severity_type 1
# 996  15486   location 821               0  event_type 11  severity_type 1
# 997   9033  location 1061               2  event_type 11  severity_type 1
# 998   9033  location 1061               2  event_type 11  severity_type 1
# 999   9033  location 1061               2  event_type 15  severity_type 1
#
#      log_feature  volume
# 0    feature 312      19
# 1    feature 232      19
# ...

# %%
df_1.tail()
# Out:
#         id       location  fault_severity     event_type    severity_type  \
# 995  15486   location 821               0  event_type 11  severity_type 1
# 996  15486   location 821               0  event_type 11  severity_type 1
# 997   9033  location 1061               2  event_type 11  severity_type 1
# 998   9033  location 1061               2  event_type 11  severity_type 1
# 999   9033  location 1061               2  event_type 15  severity_type 1
#
#      log_feature  volume
# 995   feature 80       2
# 996   feature 71       1
# 997   feature 80       4
# 998  feature 201       6
# 999   feature 80       4

# %%
df_2
# Out:
#           id       location  fault_severity     event_type    severity_type  \
# 1000    9033  location 1061               2  event_type 15  severity_type 1
# 1001    9959   location 714               0  event_type 11  severity_type 1
# 1002    9959   location 714               0  event_type 11  severity_type 1
# 1003    9959   location 714               0  event_type 11  severity_type 1
# 1004    9959   location 714               0  event_type 11  severity_type 1
# ...      ...            ...             ...            ...              ...
# 46726  15189     location 7               0  event_type 11  severity_type 1
# 46727  15189     location 7               0  event_type 11  severity_type 1
# 46728  17067   location 885               0  event_type 11  severity_type 1
# 46729  17067   location 885               0  event_type 11  severity_type 1
# 46730  17067   location 885               0  event_type 11  severity_type 1
#
#        log_feature  volume
# 1000   feature 201       6
# ...

# %% [markdown]
# ###3 Concat the two dataframes.

# %%
df = pd.concat([df_1,df_2])

# %% [markdown]
# ###4 Handle duplicates.

# %%
nodupe = df.drop_duplicates(subset=['id'])
nodupe
# Out:
#           id       location  fault_severity     event_type    severity_type  \
# 0      14121   location 118               1  event_type 34  severity_type 2
# 4       9320    location 91               0  event_type 34  severity_type 2
# 8      14394   location 152               1  event_type 35  severity_type 2
# 12      8218   location 931               1  event_type 15  severity_type 1
# 18     14804   location 120               0  event_type 34  severity_type 1
# ...      ...            ...             ...            ...              ...
# 46716    870   location 167               0  event_type 34  severity_type 2
# 46720  18068   location 106               0  event_type 20  severity_type 1
# 46722  14111  location 1086               2  event_type 15  severity_type 2
# 46724  15189     location 7               0  event_type 11  severity_type 1
# 46728  17067   location 885               0  event_type 11  severity_type 1
#
#        log_feature  volume
# 0      feature 312      19
# ...

# %%
nodupe.reset_index(drop=True)
# Out:
#          id       location  fault_severity     event_type    severity_type  \
# 0     14121   location 118               1  event_type 34  severity_type 2
# 1      9320    location 91               0  event_type 34  severity_type 2
# 2     14394   location 152               1  event_type 35  severity_type 2
# 3      8218   location 931               1  event_type 15  severity_type 1
# 4     14804   location 120               0  event_type 34  severity_type 1
# ...     ...            ...             ...            ...              ...
# 7376    870   location 167               0  event_type 34  severity_type 2
# 7377  18068   location 106               0  event_type 20  severity_type 1
# 7378  14111  location 1086               2  event_type 15  severity_type 2
# 7379  15189     location 7               0  event_type 11  severity_type 1
# 7380  17067   location 885               0  event_type 11  severity_type 1
#
#       log_feature  volume
# 0     feature 312      19
# ...
