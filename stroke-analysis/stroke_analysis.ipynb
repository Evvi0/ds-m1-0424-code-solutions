# %%
import numpy as np
import pandas as pd

# %%
stroke = pd.read_csv('/content/healthcare-dataset-stroke-data.csv')

# %%
stroke
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %% [markdown]
# #1

# %%
stroke.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %% [markdown]
# #2

# %%
stroke.select_dtypes(include=float).describe()
# Out:
#                age  avg_glucose_level          bmi
# count  5110.000000        5110.000000  4909.000000
# mean     43.226614         106.147677    28.893237
# std      22.612647          45.283560     7.854067
# min       0.080000          55.120000    10.300000
# 25%      25.000000          77.245000    23.500000
# 50%      45.000000          91.885000    28.100000
# 75%      61.000000         114.090000    33.100000
# max      82.000000         271.740000    97.600000

# %% [markdown]
# #3

# %%
stroke.groupby("stroke").describe()
# Out:
#             id                                                                \
#          count          mean           std    min      25%      50%      75%
# stroke
# 0       4861.0  36487.236371  21120.133386   67.0  17762.0  36958.0  54497.0
# 1        249.0  37115.068273  21993.344872  210.0  17013.0  36706.0  56669.0
#
#                     age             ... avg_glucose_level             bmi  \
#             max   count       mean  ...               75%     max   count
# stroke                              ...
# 0       72940.0  4861.0  41.971545  ...            112.83  267.76  4700.0
# 1       72918.0   249.0  67.728193  ...            196.71  271.74   209.0
#
#
#              mean       std   min   25%   50%   75%   max
# stroke
# 0       28.823064  7.908287  10.3  23.4  28.0  33.1  97.6
# 1       30.471292  6.329452  16.9  26.4  29.7  33.7  56.6
#
# [2 rows x 48 columns]

# %% [markdown]
# #4

# %%
stroke1 = stroke.groupby('stroke').describe()
stroke1[1:]
# Out:
#            id                                                                \
#         count          mean           std    min      25%      50%      75%
# stroke
# 1       249.0  37115.068273  21993.344872  210.0  17013.0  36706.0  56669.0
#
#                    age             ... avg_glucose_level            bmi  \
#             max  count       mean  ...               75%     max  count
# stroke                             ...
# 1       72918.0  249.0  67.728193  ...            196.71  271.74  209.0
#
#
#              mean       std   min   25%   50%   75%   max
# stroke
# 1       30.471292  6.329452  16.9  26.4  29.7  33.7  56.6
#
# [1 rows x 48 columns]

# %% [markdown]
# #5

# %%
stroke2 = stroke.groupby("stroke").describe()
stroke2.select_dtypes(include=float)
# Out:
#             id                                                                \
#          count          mean           std    min      25%      50%      75%
# stroke
# 0       4861.0  36487.236371  21120.133386   67.0  17762.0  36958.0  54497.0
# 1        249.0  37115.068273  21993.344872  210.0  17013.0  36706.0  56669.0
#
#                     age             ... avg_glucose_level             bmi  \
#             max   count       mean  ...               75%     max   count
# stroke                              ...
# 0       72940.0  4861.0  41.971545  ...            112.83  267.76  4700.0
# 1       72918.0   249.0  67.728193  ...            196.71  271.74   209.0
#
#
#              mean       std   min   25%   50%   75%   max
# stroke
# 0       28.823064  7.908287  10.3  23.4  28.0  33.1  97.6
# 1       30.471292  6.329452  16.9  26.4  29.7  33.7  56.6
#
# [2 rows x 48 columns]

# %% [markdown]
# #6

# %%
stroke.select_dtypes(include=int)
# Out:
#          id  hypertension  heart_disease  stroke
# 0      9046             0              1       1
# 1     51676             0              0       1
# 2     31112             0              1       1
# 3     60182             0              0       1
# 4      1665             1              0       1
# ...     ...           ...            ...     ...
# 5105  18234             1              0       0
# 5106  44873             0              0       0
# 5107  19723             0              0       0
# 5108  37544             0              0       0
# 5109  44679             0              0       0
#
# [5110 rows x 4 columns]

# %% [markdown]
# #7

# %%
stroke_group = stroke.groupby(['hypertension', 'heart_disease'])
print(stroke_group)

# %% [markdown]
# #8

# %%
stroke_group.get_group((1,1))
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 6     53882    Male  74.0             1              1          Yes
# 35      712  Female  82.0             1              1           No
# 115   53401    Male  71.0             1              1           No
# 143   37651  Female  69.0             1              1           No
# 171   60739  Female  79.0             1              1           No
# ...     ...     ...   ...           ...            ...          ...
# 4590  19271  Female  82.0             1              1          Yes
# 4638  72160    Male  72.0             1              1          Yes
# 4684  49894  Female  78.0             1              1          Yes
# 4784  70497  Female  81.0             1              1          Yes
# 4855  42563  Female  57.0             1              1          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %% [markdown]
# #9

# %%
stroke_group['id'].nunique()
# Out:
# hypertension  heart_disease
# 0             0                4400
#               1                 212
# 1             0                 434
#               1                  64
# Name: id, dtype: int64

# %% [markdown]
# #10

# %%
stroke_group['stroke'].describe()[['mean','std']]
# Out:
#                                 mean       std
# hypertension heart_disease
# 0            0              0.033864  0.180899
#              1              0.160377  0.367824
# 1            0              0.122120  0.327802
#              1              0.203125  0.405505

# %%
print("hello")
# Out:
# hello
