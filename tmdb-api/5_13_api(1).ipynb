# %% [markdown]
# ###Exercises###

# %%
import requests
import pandas as pd

# %%
base_movie_url = "https://api.themoviedb.org/3/search/movie"

# %%
api_key = 'd717d35008ef9bc2d50ccee771870771'

# %%
movie_url = requests.get(f'https://api.themoviedb.org/3/search/movie?query=star wars&page=1&api_key={api_key}')
movie_url
# Out:
# <Response [200]>

# %%
movie_url.content
# Out:
# b'{"page":1,"results":[{"adult":false,"backdrop_path":"/4qCqAdHcNKeAHcK8tJ8wNJZa9cx.jpg","genre_ids":[12,28,878],"id":11,"original_language":"en","original_title":"Star Wars","overview":"Princess Leia is captured and held hostage by the evil Imperial forces in their effort to take over the galactic Empire. Venturesome Luke Skywalker and dashing captain Han Solo team together with the loveable robot duo R2-D2 and C-3PO to rescue the beautiful princess and restore peace and justice in the Empire.","popularity":440.981,"poster_path":"/6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg","release_date":"1977-05-25","title":"Star Wars","video":false,"vote_average":8.203,"vote_count":20003},{"adult":false,"backdrop_path":"/epVMXf10WqFkONzKR8V76Ypj5Y3.jpg","genre_ids":[12,28,878],"id":181808,"original_language":"en","original_title":"Star Wars: The Last Jedi","overview":"Rey develops her newly discovered abilities with the guidance of Luke Skywalker, who is unsettled by the strength of her powers. Meanwhile, t
# ...

# %%
movie_url.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/4qCqAdHcNKeAHcK8tJ8wNJZa9cx.jpg',
#    'genre_ids': [12, 28, 878],
#    'id': 11,
#    'original_language': 'en',
#    'original_title': 'Star Wars',
#    'overview': 'Princess Leia is captured and held hostage by the evil Imperial forces in their effort to take over the galactic Empire. Venturesome Luke Skywalker and dashing captain Han Solo team together with the loveable robot duo R2-D2 and C-3PO to rescue the beautiful princess and restore peace and justice in the Empire.',
#    'popularity': 440.981,
#    'poster_path': '/6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg',
#    'release_date': '1977-05-25',
#    'title': 'Star Wars',
#    'video': False,
#    'vote_average': 8.203,
#    'vote_count': 20003},
#   {'adult': False,
#    'backdrop_path': '/epVMXf10WqFkONzKR8V76Ypj5Y3.jpg',
#    'genre_ids': [12, 28, 878],
#    'id': 181808,
#    'original_language': 'en',
#    'original_title': 'Star Wars: The Last Jedi',
# ...

# %%
total_pages = movie_url.json()["total_pages"]

all_pages = []

for page in range(1, total_pages+1):
    new_url = url + f"&page={page}"
    page_data = requests.get(new_url)

    if page_data.status_code == 200:
      all_pages += page_data.json()['results']
    else:
      raise Exception("bad status code: " + str(page_data.status_code))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 6
#       3 all_pages = []
#       5 for page in range(1, total_pages+1):
# ----> 6     new_url = url + f"&page={page}"
#       7     page_data = requests.get(new_url)
#       9     if page_data.status_code == 200:
#
# NameError: name 'url' is not defined

# %%
df_star_wars = pd.DataFrame(movie_url.json()['results'])
df_star_wars
# Out:
#     adult                     backdrop_path                        genre_ids  \
# 0   False  /4qCqAdHcNKeAHcK8tJ8wNJZa9cx.jpg                    [12, 28, 878]
# 1   False  /epVMXf10WqFkONzKR8V76Ypj5Y3.jpg                    [12, 28, 878]
# 2   False  /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg                    [12, 28, 878]
# 3   False  /jn52me8AagfNt7r84SgQbV0R9ZG.jpg                    [12, 28, 878]
# 4   False  /hDvk6O2vehwsZBdNsMSGmAVdiUn.jpg                    [878, 12, 28]
# 5   False  /wDe8LzwuvHYYiuwyNfxdYQq8ti4.jpg                    [12, 28, 878]
# 6   False  /6t8ES1d12OzWyCGxBeDYLHoaDrT.jpg                    [28, 12, 878]
# 7   False  /abwxHfymXGAbbH3lo9PDEJEfvtW.jpg                    [12, 28, 878]
# 8   False  /5vDuLrjJXFS9PTF7Q1xzobmYKR9.jpg                    [12, 28, 878]
# 9   False  /wBBONMlfnrU2GxxN7X2pFDdZuRB.jpg         [16, 12, 10751, 14, 878]
# 10  False  /iflKt34Ck2JpY2PY9wW1zwdJgJi.jpg             [16, 878, 12, 10751]
# ...

# %%
df_star_wars.sort_values('popularity')
# Out:
#     adult                     backdrop_path                        genre_ids  \
# 18  False  /98CXGiN2bIh6HUnRjFNGgA9o4FZ.jpg                             [99]
# 12  False                              None                             [99]
# 15  False                              None                             [99]
# 9   False  /wBBONMlfnrU2GxxN7X2pFDdZuRB.jpg         [16, 12, 10751, 14, 878]
# 19  False  /1Lhc32P0a62BgMFgd20wXR1osR3.jpg         [16, 10751, 878, 12, 35]
# 14  False  /vV5knD9jlW8QaOhCgf4129hbIIh.jpg      [16, 10751, 878, 35, 10770]
# 16  False  /f53Jujiap580mgfefID0T0g2e17.jpg      [16, 10751, 878, 35, 10770]
# 10  False  /iflKt34Ck2JpY2PY9wW1zwdJgJi.jpg             [16, 878, 12, 10751]
# 11  False  /uNjBnOmdjZoiWTLQ938YJZ1cYVU.jpg  [16, 35, 10751, 878, 12, 10770]
# 13  False  /7nHXstkbnX8t7fKICraMJkuPhK5.jpg          [14, 878, 10751, 10770]
# 17  False  /eVA4ztLIuPEsokkgQ3NRt9rTRVh.jpg                [16, 28, 878, 12]
# ...

# %%
pip install tmdbsimple
# Out:
# ...
#   Using cached tmdbsimple-2.9.1-py3-none-any.whl.metadata (6.9 kB)
# ...
# Using cached tmdbsimple-2.9.1-py3-none-any.whl (38 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tmdbsimple as tmdb

# %%
tmdb.API_KEY = 'd717d35008ef9bc2d50ccee771870771'

# %%
tmdb.REQUESTS_TIMEOUT = 5

# %%
tmdb.REQUESTS_SESSION = requests.Session()

# %%
search = tmdb.Search()
response = search.movie(query = 'star wars')
star_wars = []
for s in search.results:
    star_wars.append(s['title'])
    star_wars.append(s['id'])
    star_wars.append(s['release_date'])
    star_wars.append(s['popularity'])

# %%
search = tmdb.Search()
response = search.movie(query = 'star wars')
response
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/4qCqAdHcNKeAHcK8tJ8wNJZa9cx.jpg',
#    'genre_ids': [12, 28, 878],
#    'id': 11,
#    'original_language': 'en',
#    'original_title': 'Star Wars',
#    'overview': 'Princess Leia is captured and held hostage by the evil Imperial forces in their effort to take over the galactic Empire. Venturesome Luke Skywalker and dashing captain Han Solo team together with the loveable robot duo R2-D2 and C-3PO to rescue the beautiful princess and restore peace and justice in the Empire.',
#    'popularity': 440.981,
#    'poster_path': '/6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg',
#    'release_date': '1977-05-25',
#    'title': 'Star Wars',
#    'video': False,
#    'vote_average': 8.203,
#    'vote_count': 20003},
#   {'adult': False,
#    'backdrop_path': '/epVMXf10WqFkONzKR8V76Ypj5Y3.jpg',
#    'genre_ids': [12, 28, 878],
#    'id': 181808,
#    'original_language': 'en',
#    'original_title': 'Star Wars: The Last Jedi',
# ...

# %%
list(response)
# Out:
# ['page', 'results', 'total_pages', 'total_results']

# %%
df = pd.DataFrame(response['results'])
df
# Out:
#     adult                     backdrop_path                        genre_ids  \
# 0   False  /4qCqAdHcNKeAHcK8tJ8wNJZa9cx.jpg                    [12, 28, 878]
# 1   False  /epVMXf10WqFkONzKR8V76Ypj5Y3.jpg                    [12, 28, 878]
# 2   False  /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg                    [12, 28, 878]
# 3   False  /jn52me8AagfNt7r84SgQbV0R9ZG.jpg                    [12, 28, 878]
# 4   False  /hDvk6O2vehwsZBdNsMSGmAVdiUn.jpg                    [878, 12, 28]
# 5   False  /wDe8LzwuvHYYiuwyNfxdYQq8ti4.jpg                    [12, 28, 878]
# 6   False  /6t8ES1d12OzWyCGxBeDYLHoaDrT.jpg                    [28, 12, 878]
# 7   False  /abwxHfymXGAbbH3lo9PDEJEfvtW.jpg                    [12, 28, 878]
# 8   False  /5vDuLrjJXFS9PTF7Q1xzobmYKR9.jpg                    [12, 28, 878]
# 9   False  /wBBONMlfnrU2GxxN7X2pFDdZuRB.jpg         [16, 12, 10751, 14, 878]
# 10  False  /iflKt34Ck2JpY2PY9wW1zwdJgJi.jpg             [16, 878, 12, 10751]
# ...

# %%
star_wars
# Out:
# ['Star Wars',
#  11,
#  '1977-05-25',
#  440.981,
#  'Star Wars: The Last Jedi',
#  181808,
#  '2017-12-13',
#  87.277,
#  'Star Wars: The Force Awakens',
#  140607,
#  '2015-12-15',
#  97.5,
#  'Star Wars: The Rise of Skywalker',
#  181812,
#  '2019-12-18',
#  84.191,
#  'Solo: A Star Wars Story',
#  348350,
#  '2018-05-15',
#  75.833,
#  'Star Wars: Episode I - The Phantom Menace',
#  1893,
#  '1999-05-19',
#  80.778,
#  'Rogue One: A Star Wars Story',
#  330459,
#  '2016-12-14',
#  48.728,
#  'Star Wars: Episode II - Attack of the Clones',
#  1894,
#  '2002-05-15',
#  51.264,
#  'Star Wars: Episode III - Revenge of the Sith',
#  1895,
#  '2005-05-17',
#  62.073,
#  "Doraemon: Nobita's Little Star Wars",
#  161704,
#  '1985-03-16',
#  15.932,
#  "Doraemon the Movie: Nobita's Little Star Wars 2021",
#  782054,
#  '2022-03-04',
#  18.621,
#  'Phineas and Ferb: Star Wars',
#  392216,
#  '2014-07-26',
#  21.787,
#  'Star Wars: Heroes & Villains',
#  432134,
#  '2005-05-03',
#  3.136,
# ...

# %%
import json

# %%
movie = tmdb.Movies(11)
response = movie.info()
movie.title
# Out:
# 'Star Wars'

# %%
movie.budget
# Out:
# 11000000

# %%
df.sort_values('popularity')
# Out:
#     adult                     backdrop_path                        genre_ids  \
# 18  False  /98CXGiN2bIh6HUnRjFNGgA9o4FZ.jpg                             [99]
# 12  False                              None                             [99]
# 15  False                              None                             [99]
# 9   False  /wBBONMlfnrU2GxxN7X2pFDdZuRB.jpg         [16, 12, 10751, 14, 878]
# 19  False  /1Lhc32P0a62BgMFgd20wXR1osR3.jpg         [16, 10751, 878, 12, 35]
# 14  False  /vV5knD9jlW8QaOhCgf4129hbIIh.jpg      [16, 10751, 878, 35, 10770]
# 16  False  /f53Jujiap580mgfefID0T0g2e17.jpg      [16, 10751, 878, 35, 10770]
# 10  False  /iflKt34Ck2JpY2PY9wW1zwdJgJi.jpg             [16, 878, 12, 10751]
# 11  False  /uNjBnOmdjZoiWTLQ938YJZ1cYVU.jpg  [16, 35, 10751, 878, 12, 10770]
# 13  False  /7nHXstkbnX8t7fKICraMJkuPhK5.jpg          [14, 878, 10751, 10770]
# 17  False  /eVA4ztLIuPEsokkgQ3NRt9rTRVh.jpg                [16, 28, 878, 12]
# ...
